# %%
import pandas as pd
data_1=pd.read_csv(r"C:\Users\PIYUSH\Desktop\play_Store_data\googleplaystore.csv")
data_2=pd.read_csv(r"C:\Users\PIYUSH\Desktop\play_Store_data\googleplaystore_user_reviews.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data_1.shape
# Out:
# (10841, 13)

# %%
data_1.dropna(how='any',inplace=True)

# %%
data_1.shape
# Out:
# (9360, 13)

# %%
data_1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
data_1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
g = sns.kdeplot(data_1.Rating, color="Green", shade = True)
g.set_xlabel("Rating")
g.set_ylabel("Frequency")
plt.title('Distribution of Rating',size = 30)
# Out:
# Text(0.5, 1.0, 'Distribution of Rating')

# %%
len(data_1.Category.unique())
# Out:
# 33

# %%
g = sns.countplot(x="Category",data=data_1, palette = "Set1")
g.set_xticklabels(g.get_xticklabels(), rotation=90, ha="right")
g 
plt.title('Count of app in each category',size = 40)
# Out:
# Text(0.5, 1.0, 'Count of app in each category')

# %%
g = sns.catplot(x="Category",y="Rating",data=data_1, kind="box", height = 10 ,
palette = "Set1")
g.despine(left=True)
g.set_xticklabels(rotation=90)
g.set( xticks=range(0,34))
g = g.set_ylabels("Rating")
plt.title('Boxplot of Rating VS Category',size = 20)
# Out:
# Text(0.5, 1.0, 'Boxplot of Rating VS Category')

# %%
len(data_1["Content Rating"].unique())
# Out:
# 6

# %%
g = sns.countplot(x="Content Rating",data=data_1, palette = "Set1")
g.set_xticklabels(g.get_xticklabels(), rotation=90, ha="right")
g 
plt.title('Count of app in each category',size = 40)
# Out:
# Text(0.5, 1.0, 'Count of app in each category')

# %%
g = sns.catplot(x="Content Rating",y="Rating",data=data_1, kind="box", height = 10 ,
palette = "Set1")
g.despine(left=True)
g.set_xticklabels(rotation=90)
g.set( xticks=range(0,34))
g = g.set_ylabels("Rating")
plt.title('Boxplot of Rating VS Category',size = 10)
# Out:
# Text(0.5, 1.0, 'Boxplot of Rating VS Category')

# %%
len(data_1.Type.unique())
# Out:
# 2

# %%
g = sns.countplot(x="Type",data=data_1, palette = "Set1")
g.set_xticklabels(g.get_xticklabels(), rotation=90, ha="right")
g 
plt.title('Count of app in each category',size = 40)
# Out:
# Text(0.5, 1.0, 'Count of app in each category')

# %%
g = sns.catplot(x="Type",y="Rating",data=data_1, kind="box", height = 10 ,
palette = "Set1")
g.despine(left=True)
g.set_xticklabels(rotation=90)
g.set( xticks=range(0,34))
g = g.set_ylabels("Rating")
plt.title('Boxplot of Rating VS Category',size = 10)
# Out:
# Text(0.5, 1.0, 'Boxplot of Rating VS Category')

# %%
len(data_1.Genres.unique())
# Out:
# 115

# %%
g = sns.countplot(x="Genres",data=data_1, palette = "Set1")
g.set_xticklabels(g.get_xticklabels(), rotation=90, ha="right")
g 
plt.title('Count of app in each category',size = 2)
# Out:
# Text(0.5, 1.0, 'Count of app in each category')

# %%
data_1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data_1["Category"].describe()
# Out:
# count      10841
# unique        34
# top       FAMILY
# freq        1972
# Name: Category, dtype: object

# %%
data_1["Size"].describe()
# Out:
# count                  10841
# unique                   462
# top       Varies with device
# freq                    1695
# Name: Size, dtype: object

# %%
data_1["Type"].describe()
# Out:
# count     10840
# unique        3
# top        Free
# freq      10039
# Name: Type, dtype: object

# %%
data_1["Content Rating"].describe()
# Out:
# count        10840
# unique           6
# top       Everyone
# freq          8714
# Name: Content Rating, dtype: object

# %%
data_1["Genres"].describe()
# Out:
# count     10841
# unique      120
# top       Tools
# freq        842
# Name: Genres, dtype: object

# %%
data_1.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
max(data_1["Rating"])
# Out:
# 19.0
